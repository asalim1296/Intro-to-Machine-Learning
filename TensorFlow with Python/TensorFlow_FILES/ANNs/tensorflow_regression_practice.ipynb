# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('../DATA/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df['bedrooms'].max()
# Out:
# 33

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(10,5))
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='price',y='long',data=df)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='price',y='lat',data=df)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='long',y='lat',hue='price',data=df,palette='coolwarm')
# price outliers are not recognizable since they're very few in the dataset, so we'll drop the most high prices(1% of the dataset)

# %%
df.sort_values(by='price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
lowest_prices=df.sort_values(by='price',ascending=False).iloc[216:]

# %%
lowest_prices.head()
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 6329    824059321    6/2/2014  1970000.0         4       3.50         4370
# 12271  1923000260  10/15/2014  1960000.0         5       4.50         6200
# 9166   3124059023   2/13/2015  1960000.0         3       1.75         3330
# 12565  2806300065   4/22/2015  1960000.0         4       4.00         4430
# 1150   4055701200   4/21/2015  1960000.0         4       2.75         3120
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 6329       8510     2.0           0     1  ...     10        3610
# 12271     23373     3.0           0     1  ...     11        5050
# 9166      12566     1.0           1     4  ...      8        1940
# 12565     31353     2.0           0     0  ...     12        4430
# 1150       7898     1.0           1     4  ...      8        1560
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue='price',data=lowest_prices,palette='RdYlGn',alpha=0.2,edgecolor=None)
# note how that the nearest to the water the highest the price is

# %%
sns.boxplot(x='waterfront',y='price',data=df)# houses next to the water are more expensive

# %%
df.corr()['price'].sort_values(ascending=False)# correlation between price and other attributes
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.397370
# sqft_basement    0.323799
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.266398
# floors           0.256804
# yr_renovated     0.126424
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
df=df.drop('id',axis=1)

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df['year']=df['date'].apply(lambda x:x.year)
df['month']=df['date'].apply(lambda x:x.month)

# %%
df.drop('monthe',axis=1,inplace=True)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['month'])

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x='month',y='price',data=df)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='year',y='price',data=df)

# %%
plt.figure(figsize=(10,8))
df.groupby('month')['price'].mean().plot()# mean value for selling price of the houses by the months

# %%
df.groupby('year').mean()['price'].plot()

# %%
plt.figure(figsize=(10,8))
df.groupby('month')['month'].count().plot()

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.drop('zipcode',axis=1,inplace=True)

# %%
df['yr_renovated'].value_counts()# we won't feature engineer this since it makes sense that higher value correlate to high price
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()# same goes here
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
X=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
X_test.shape
# Out:
# (6480, 19)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

# %%
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

model.add(Dense(1))
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,validation_data=(X_test,y_test.values),batch_size=128,epochs=400)
# validation_data: Data on which to evaluate the loss and any model metrics at the end of each epoch. The model will not be trained on this data.
#validation_data measure how well our model is performing during the training process without effecting the trained result
# Out:
# Epoch 1/400
# 119/119 [==============================] - 6s 12ms/step - loss: 430243708928.0000 - val_loss: 418930196480.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 3ms/step - loss: 429037453312.0000 - val_loss: 414465490944.0000
# Epoch 3/400
# 119/119 [==============================] - 0s 3ms/step - loss: 409760497664.0000 - val_loss: 369316691968.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 3ms/step - loss: 313366511616.0000 - val_loss: 218845544448.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 152299585536.0000 - val_loss: 100674674688.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 4ms/step - loss: 99265495040.0000 - val_loss: 94001143808.0000
# Epoch 7/400
# 119/119 [==============================] - 1s 4ms/step - loss: 96336437248.0000 - val_loss: 92418539520.0000
# Epoch 8/400
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,explained_variance_score

# %%
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    4.302437e+11  4.189302e+11
# 1    4.290375e+11  4.144655e+11
# 2    4.097605e+11  3.693167e+11
# 3    3.133665e+11  2.188455e+11
# 4    1.522996e+11  1.006747e+11
# ..            ...           ...
# 395  2.378092e+10  2.211295e+10
# 396  2.373428e+10  2.222176e+10
# 397  2.367561e+10  2.250744e+10
# 398  2.371546e+10  2.200851e+10
# 399  2.362579e+10  2.194037e+10
#
# [400 rows x 2 columns]

# %%
pd.DataFrame(model.history.history).plot() # we can tell that there's no overfitting in our model

# %%
pred=model.predict(X_test)
# Out:
# 203/203 [==============================] - 1s 2ms/step

# %%
mean_absolute_error(pred,y_test)
# Out:
# 88258.12393633054

# %%
mean_squared_error(pred,y_test)
# Out:
# 21940363713.623158

# %%
np.sqrt(mean_squared_error(pred,y_test))
# Out:
# 148122.79943892214

# %%
explained_variance_score(y_test,pred)
# Out:
# 0.8346764346479496

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.scatter(x=y_test,y=pred) # our predictions
plt.plot(y_test,y_test,'r')# the perfect fitting

# %%
errors=y_test.values.reshape(6480,1)-pred

# %%
plt.figure(figsize=(12,8))
sns.distplot(errors)
